# %% [markdown]
# # train pix2pix gan model. document in neptune

# %% [markdown]
# ## detect gpu available

# %%
import tensorflow as tf

# check the status of GPU
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.6.2
# Num GPUs Available:  1

# %% [markdown]
# ## set the neptune

# %%
# define if the documenting process should go on

DOCUMENT = True
EPOCHS = 1000
batch_size = 16

# %%
# neptune document. change the document here

import neptune.new as neptune
from neptune.new.integrations.tensorflow_keras import NeptuneCallback

if DOCUMENT:

    run = neptune.init(
        project="leeleeroy/digitalConfocal-zebrafish",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3YjVjOGVmZi04MjA4LTQ4N2QtOWIzYy05M2YyZWI1NzY3MmEifQ==",
        name = "UNet2D_256_vanilla",
    ) # necessary credentials, the name could be used to reproduce the results 

    # for callbacks in training


    neptune_cbk = NeptuneCallback(run=run, base_namespace='metrics')  # neptune for the training process
    
    # neptune document the hyper param.

    PARAMS = {
              "optimizer": {"learning_rate": 0.0001, "optimizer": "Adam"},
              'epochs': EPOCHS,
              'batch_size':batch_size}

    # log hyper-parameters
    run['hyper-parameters'] = PARAMS
    run["sys/tags"].add(["vanilla", "epochs:" + str(EPOCHS)], 'deep512')
# Out:
# https://app.neptune.ai/leeleeroy/digitalConfocal-zebrafish/e/DIGZ-14
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# /home/li52/.conda/envs/LM/lib/python3.7/site-packages/neptune/new/internal/utils/git.py:35: UserWarning: GitPython could not be initialized
#   warnings.warn("GitPython could not be initialized")
# /home/li52/.conda/envs/LM/lib/python3.7/site-packages/neptune/new/internal/utils/git.py:35: UserWarning: GitPython could not be initialized
#   warnings.warn("GitPython could not be initialized")

# %% [markdown]
# ## load in data and inspect with generator

# %% [markdown]
# ### load in

# %%
import os 
import numpy as np
from dataGenerator import imageLoader
import keras
import matplotlib.pyplot as plt
import glob
import random

# %%
# visualize func

def visusalizeIMG(n_slice, test_img, test_msk):
    # n_slice = random.randint(0, test_img.shape[2])
    plt.figure(figsize=(8, 8))

    plt.subplot(121)
    plt.imshow(test_img[n_slice,:,:], cmap='gray')
    plt.title('image')
    plt.subplot(122)
    plt.imshow(test_msk[n_slice,:,:], cmap='gray')
    plt.title('mask')
    plt.show()
    
# visualization for two images

def subShow(IMG1, IMG2):
    plt.figure()
    plt.subplot(1,2,1)
    plt.imshow(IMG1, cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(IMG2, cmap='gray')
    plt.show()

# %%
# define the data path

DATA_PATH = '/home/li52/code/LM/digitalConfocal/data/zebra15/inputData/'  # use the definite path!

# training
train_img_dir = DATA_PATH + 'train/images/'
train_msk_dir = DATA_PATH + 'train/masks/'
train_img_list = sorted(os.listdir(train_img_dir))  # ensure img and msk paired
train_msk_list = sorted(os.listdir(train_msk_dir))

# testing
test_img_dir = DATA_PATH + 'test/images/'
test_msk_dir = DATA_PATH + 'test/masks/'
test_img_list = sorted(os.listdir(test_img_dir))
test_msk_list = sorted(os.listdir(test_msk_dir))

# validation
val_img_dir = DATA_PATH + 'val/images/'
val_msk_dir = DATA_PATH + 'val/masks/'
val_img_list = sorted(os.listdir(val_img_dir))
val_msk_list = sorted(os.listdir(val_msk_dir))

print('train images:', len(train_img_list))
print('val images:', len(val_img_list))
print('test images:', len(test_img_list))
# Out:
# train images: 240
# val images: 30
# test images: 30

# %% [markdown]
# ### data generator

# %%
# data generator for training

# batch_size = 16

# RESIZE = True  # resize as [256, 256]

train_img_datagen = imageLoader(train_img_dir, train_img_list,
                               train_msk_dir, train_msk_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list,
                             val_msk_dir, val_msk_list, batch_size)

# %%
# visualize the data generator

img, msk = train_img_datagen.__next__()

print('image gen:', img.shape, img.min(), img.max())
print('mask gen:', msk.shape, msk.min(), msk.max(), np.unique(msk))

n_slice = random.randint(0, img.shape[0]-1)
# n_slice = 15
print('slice num:', n_slice)
visusalizeIMG(n_slice, img, msk)
# Out:
# image gen: (16, 256, 256) 0.0 0.984313725490196
# mask gen: (16, 256, 256) 0.0 1.0 [0. 1.]
# slice num: 0

# %% [markdown]
# ## model configuration

# %% [markdown]
# ### pix2pix GAN.

# %%
import numpy as np
from numpy.random import randint

from tensorflow.keras.optimizers import Adam
from keras.initializers import RandomNormal  #  for normalization
import tensorflow.keras as k
from tensorflow.keras.utils import plot_model  # visualize the model

import matplotlib.pyplot as plt

from models.pix2pix import *

# %%
# configure the train process

def trainModel(g_model, d_model, gan_model, dataset, n_epochs=20, n_batch=1):
    # save the training information
    loss_all = []
    
    # output shape of the discriminator
    n_patch = d_model.output_shape[1]  
    
    # unpack dataset
    trainA, trainB = dataset
    
    
    # number of the baches per epoch
    bat_per_epo = int(len(trainA) / n_batch)
    # number of training iterations
    n_steps = bat_per_epo * n_epochs  # !!! altogether iterations
    
    # enumerate epochs
    for i in range(n_steps):
        # select batch of real images
        [X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
        # generate batch of fake images
        X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
        # update D for real images
        d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)  # update weights on one batch
        # update D for fake images
        d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)  # try to generate map images
        
        # update the G
        g_loss, _ , _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
        
        # collect the loss information
        loss_all.append([d_loss1, d_loss2, g_loss])
        
#         # Log generator loss
#         run["training/g_loss"].log(loss)  # use the neptune to document the loss

#         # Log D loss
#         run["training/d_loss1"].log(acc)
        
        # summarize the performance
        print('>%d, d1[%.3f] d2[%.3f] g[%.3f]' % (i+1, d_loss1, d_loss2, g_loss))
        # model performance
        if (i+1) % (bat_per_epo * 10) == 0:
            summarize_performance(i, g_model, dataset)
            
    np.save('./pix2pix/pix2pix_300.npy', np.asarray(loss_all))

# %% [markdown]
# ## train

# %%
import tensorflow.keras as k

# steps and epochs
steps_per_epoch = len(train_img_list) // batch_size
val_steps_per_epoch = len(val_img_list) // batch_size

print('train steps/epoch', steps_per_epoch)
print('val steps/epoch', steps_per_epoch)

# call backs for documentation

if DOCUMENT:
    callbacks = [
        # k.callbacks.EarlyStopping(patience=15, monitor='val_loss'),
        neptune_cbk, 
        k.callbacks.TensorBoard(log_dir = './tensorboard/UNet2D')  # save in new folder in hemera. Also update in neptune
    ]
else:
    callbacks = [
        # k.callbacks.EarlyStopping(patience=15, monitor='val_loss'),
        k.callbacks.TensorBoard(log_dir = './tensorboard/UNet2D')  
    ]
# Out:
# train steps/epoch 15
# val steps/epoch 15
# 2022-08-18 23:32:06.363775: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-08-18 23:32:06.363804: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-08-18 23:32:06.363860: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-08-18 23:32:06.364316: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /trinity/shared/pkg/numlib/mpfr/3.1.4/lib:/trinity/shared/pkg/numlib/mpc/1.0.3/lib:/trinity/shared/pkg/numlib/gmp/6.1.2/lib:/trinity/shared/pkg/compiler/gcc/7.3.0/lib64:/trinity/shared/pkg/compiler/gcc/7.3.0/lib:/trinity/shared/pkg/devel/cuda/11.2/lib64:/trinity/shared/pkg/devel/cuda/11.2/lib:/trinity/shared/pkg/devel/anaconda/2021.11/lib:/trinity/shared/pkg/devel/python/3.10.4/lib/python3.10:/trinity/shared/pkg/devel/python/3.10.4/lib
# 2022-08-18 23:32:06.364525: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so'; dlerror: libcupti.so: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /trinity/shared/pkg/numlib/mpfr/3.1.4/lib:/trinity/shared/pkg/numlib/mpc/1.0.3/lib:/trinity/shared/pkg/numlib/gmp/6.1.2/lib:/trinity/shared/pkg/compiler/gcc/7.3.0/lib64:/trinity/shared/pkg/compiler/gcc/7.3.0/lib:/trinity/shared/pkg/devel/cuda/11.2/lib64:/trinity/shared/pkg/devel/cuda/11.2/lib:/trinity/shared/pkg/devel/anaconda/2021.11/lib:/trinity/shared/pkg/devel/python/3.10.4/lib/python3.10:/trinity/shared/pkg/devel/python/3.10.4/lib
# 2022-08-18 23:32:06.364567: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1666] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI could not be loaded or symbol could not be found.
# 2022-08-18 23:32:06.364728: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-08-18 23:32:06.364770: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1757] function cupti_interface_->Finalize()failed with error CUPTI could not be loaded or symbol could not be found.

# %%
# 测试用

# train per steps. inspect the loss is correct.
# caution, this training will continue

# NUM_STEPS = 4000

# for step in range(NUM_STEPS):
    
#     img, msk = train_img_datagen.__next__()
    
#     loss = model.train_on_batch(img, msk.astype('float64'))  # batch=1
    
#     print(step, loss)
    
# #     if step % 1000:
# #         model.save_weights('./model_savedG.hdf5')
        
#     if step % 100 == 0:
#         prediction = model.predict(img, batch_size=1)
#         plt.imshow(prediction[0,...],cmap='gray')
#         plt.show()
#         plt.close('all')

# %%
# train with keras model

history = model.fit(train_img_datagen,
                   steps_per_epoch=steps_per_epoch,
                   epochs=EPOCHS,
                   verbose=1, # ??
                   validation_data=val_img_datagen,
                   validation_steps=val_steps_per_epoch,
                   callbacks=callbacks)
# Out:
# Epoch 1/1000
# 2022-08-18 23:32:06.470158: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-08-18 23:32:11.309733: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
#  2/15 [===>..........................] - ETA: 3s - loss: 0.7452 - accuracy: 0.5296 - iou_score: 0.3742
# 2022-08-18 23:32:15.561571: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-08-18 23:32:15.561620: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-08-18 23:32:15.561763: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1666] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI could not be loaded or symbol could not be found.
# 2022-08-18 23:32:15.693816: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-08-18 23:32:15.693943: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1757] function cupti_interface_->Finalize()failed with error CUPTI could not be loaded or symbol could not be found.
# 2022-08-18 23:32:15.704590: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-08-18 23:32:15.707970: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-08-18 23:32:15.711583: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15
#
# 2022-08-18 23:32:15.712613: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.trace.json.gz
# 2022-08-18 23:32:15.741807: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15
#
# 2022-08-18 23:32:15.749168: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.memory_profile.json.gz
# 2022-08-18 23:32:15.751671: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15
# Dumped tool data for xplane.pb to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.xplane.pb
# Dumped tool data for overview_page.pb to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./tensorboard/UNet2D/train/plugins/profile/2022_08_18_23_32_15/gv001.cluster.kernel_stats.pb
#  6/15 [===========>..................] - ETA: 1s - loss: 0.6710 - accuracy: 0.6231 - iou_score: 0.4725WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0560s vs `on_train_batch_end` time: 0.0956s). Check your callbacks.
# 15/15 [==============================] - 12s 246ms/step - loss: 0.5433 - accuracy: 0.7408 - iou_score: 0.6346 - val_loss: 0.3960 - val_accuracy: 0.8623 - val_iou_score: 0.8101
# Epoch 2/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.3433 - accuracy: 0.8735 - iou_score: 0.8197 - val_loss: 0.2750 - val_accuracy: 0.9058 - val_iou_score: 0.8640
# Epoch 3/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.2739 - accuracy: 0.8994 - iou_score: 0.8539 - val_loss: 0.2455 - val_accuracy: 0.9119 - val_iou_score: 0.8714
# Epoch 4/1000
# 15/15 [==============================] - 2s 138ms/step - loss: 0.2483 - accuracy: 0.9045 - iou_score: 0.8608 - val_loss: 0.2194 - val_accuracy: 0.9166 - val_iou_score: 0.8791
# Epoch 5/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.2263 - accuracy: 0.9092 - iou_score: 0.8671 - val_loss: 0.1904 - val_accuracy: 0.9233 - val_iou_score: 0.8883
# Epoch 6/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.1960 - accuracy: 0.9176 - iou_score: 0.8779 - val_loss: 0.1700 - val_accuracy: 0.9284 - val_iou_score: 0.8939
# Epoch 7/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.1650 - accuracy: 0.9272 - iou_score: 0.8901 - val_loss: 0.1559 - val_accuracy: 0.9361 - val_iou_score: 0.9029
# Epoch 8/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.1359 - accuracy: 0.9414 - iou_score: 0.9096 - val_loss: 0.1681 - val_accuracy: 0.9328 - val_iou_score: 0.8968
# Epoch 9/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.1373 - accuracy: 0.9453 - iou_score: 0.9147 - val_loss: 0.2051 - val_accuracy: 0.9205 - val_iou_score: 0.8763
# Epoch 10/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.1260 - accuracy: 0.9478 - iou_score: 0.9182 - val_loss: 0.1797 - val_accuracy: 0.9304 - val_iou_score: 0.8911
# Epoch 11/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.1422 - accuracy: 0.9458 - iou_score: 0.9155 - val_loss: 0.1664 - val_accuracy: 0.9301 - val_iou_score: 0.8967
# Epoch 12/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.1767 - accuracy: 0.9259 - iou_score: 0.8877 - val_loss: 0.1650 - val_accuracy: 0.9376 - val_iou_score: 0.9067
# Epoch 13/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.1186 - accuracy: 0.9500 - iou_score: 0.9225 - val_loss: 0.1477 - val_accuracy: 0.9580 - val_iou_score: 0.9352
# Epoch 14/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0880 - accuracy: 0.9669 - iou_score: 0.9473 - val_loss: 0.1305 - val_accuracy: 0.9559 - val_iou_score: 0.9323
# Epoch 15/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0788 - accuracy: 0.9679 - iou_score: 0.9485 - val_loss: 0.1215 - val_accuracy: 0.9580 - val_iou_score: 0.9355
# Epoch 16/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.0801 - accuracy: 0.9693 - iou_score: 0.9503 - val_loss: 0.1908 - val_accuracy: 0.9575 - val_iou_score: 0.9349
# Epoch 17/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0
1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0745 - accuracy: 0.9748 - iou_score: 0.9594 - val_loss: 0.1280 - val_accuracy: 0.9631 - val_iou_score: 0.9434
# Epoch 195/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0889 - accuracy: 0.9686 - iou_score: 0.9490 - val_loss: 0.2069 - val_accuracy: 0.9606 - val_iou_score: 0.9399
# Epoch 196/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.1024 - accuracy: 0.9604 - iou_score: 0.9370 - val_loss: 0.1077 - val_accuracy: 0.9543 - val_iou_score: 0.9298
# Epoch 197/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0539 - accuracy: 0.9773 - iou_score: 0.9635 - val_loss: 0.1580 - val_accuracy: 0.9401 - val_iou_score: 0.9038
# Epoch 198/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0313 - accuracy: 0.9875 - iou_score: 0.9794 - val_loss: 0.0929 - val_accuracy: 0.9703 - val_iou_score: 0.9528
# Epoch 199/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0216 - accuracy: 0.9904 - iou_score: 0.9842 - val_loss: 0.0859 - val_accuracy: 0.9727 - val_iou_score: 0.9569
# Epoch 200/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0183 - accuracy: 0.9916 - iou_score: 0.9861 - val_loss: 0.0957 - val_accuracy: 0.9731 - val_iou_score: 0.9574
# Epoch 201/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.0177 - accuracy: 0.9913 - iou_score: 0.9856 - val_loss: 0.1207 - val_accuracy: 0.9721 - val_iou_score: 0.9554
# Epoch 202/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.0142 - accuracy: 0.9930 - iou_score: 0.9885 - val_loss: 0.1130 - val_accuracy: 0.9754 - val_iou_score: 0.9607
# Epoch 203/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0118 - accuracy: 0.9944 - iou_score: 0.9907 - val_loss: 0.1190 - val_accuracy: 0.9733 - val_iou_score: 0.9577
# Epoch 204/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0109 - accuracy: 0.9947 - iou_score: 0.9913 - val_loss: 0.1432 - val_accuracy: 0.9713 - val_iou_score: 0.9545
# Epoch 205/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0120 - accuracy: 0.9942 - iou_score: 0.9904 - val_loss: 0.1616 - val_accuracy: 0.9738 - val_iou_score: 0.9582
# Epoch 206/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0160 - accuracy: 0.9926 - iou_score: 0.9877 - val_loss: 0.1558 - val_accuracy: 0.9705 - val_iou_score: 0.9529
# Epoch 207/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0187 - accuracy: 0.9912 - iou_score: 0.9856 - val_loss: 0.1122 - val_accuracy: 0.9745 - val_iou_score: 0.9594
# Epoch 208/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0168 - accuracy: 0.9922 - iou_score: 0.9870 - val_loss: 0.1212 - val_accuracy: 0.9702 - val_iou_score: 0.9530
# Epoch 209/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0134 - accuracy: 0.9936 - iou_score: 0.9894 - val_loss: 0.1366 - val_accuracy: 0.9732 - val_iou_score: 0.9572
# Epoch 210/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0101 - accuracy: 0.9953 - iou_score: 0.9922 - val_loss: 0.1780 - val_accuracy: 0.9725 - val_iou_score: 0.9560
# Epoch 211/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0121 - accuracy: 0.9944 - iou_score: 0.9908 - val_loss: 0.1418 - val_accuracy: 0.9752 - val_iou_score: 0.9605
# Epoch 212/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0150 - accuracy: 0.9937 - iou_score: 0.9895 - val_loss: 0.1308 - val_accuracy: 0.9711 - val_iou_score: 0.9545
# Epoch 213/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0207 - accuracy: 0.9908 - iou_score: 0.9850 - val_loss: 0.1409 - val_accuracy: 0.9696 - val_iou_score: 0.9517
# Epoch 214/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0141 - accuracy: 0.9927 - iou_score: 0.9879 - val_loss: 0.1470 - val_accuracy: 0.9713 - val_iou_score: 0.9541
# Epoch 215/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0110 - accuracy: 0.9950 - iou_score: 0.9917 - val_loss: 0.1496 - val_accuracy: 0.9719 - val_iou_score: 0.9551
# Epoch 216/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0092 - accuracy: 0.9957 - iou_score: 0.9928 - val_loss: 0.1559 - val_accuracy: 0.9733 - val_iou_score: 0.9574
# Epoch 217/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0081 - accuracy: 0.9960 - iou_score: 0.9934 - val_loss: 0.1858 - val_accuracy: 0.9710 - val_iou_score: 0.9539
# Epoch 218/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0079 - accuracy: 0.9960 - iou_score: 0.9934 - val_loss: 0.1976 - val_accuracy: 0.9713 - val_iou_score: 0.9544
# Epoch 219/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0097 - accuracy: 0.9950 - iou_score: 0.9916 - val_loss: 0.2238 - val_accuracy: 0.9718 - val_iou_score: 0.9548
# Epoch 220/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0106 - accuracy: 0.9944 - iou_score: 0.9907 - val_loss: 0.2205 - val_accuracy: 0.9703 - val_iou_score: 0.9524
# Epoch 221/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0145 - accuracy: 0.9930 - iou_score: 0.9884 - val_loss: 0.1656 - val_accuracy: 0.9699 - val_iou_score: 0.9523
# Epoch 222/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0143 - accuracy: 0.9932 - iou_score: 0.9887 - val_loss: 0.1312 - val_accuracy: 0.9724 - val_iou_score: 0.9565
# Epoch 223/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0145 - accuracy: 0.9931 - iou_score: 0.9887 - val_loss: 0.1448 - val_accuracy: 0.9723 - val_iou_score: 0.9557
# Epoch 224/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.0101 - accuracy: 0.9949 - iou_score: 0.9916 - val_loss: 0.1866 - val_accuracy: 0.9700 - val_iou_score: 0.9519
# Epoch 225/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0082 - accuracy: 0.9960 - iou_score: 0.9933 - val_loss: 0.1693 - val_accuracy: 0.9729 - val_iou_score: 0.9568
# Epoch 226/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0062 - accuracy: 0.9968 - iou_score: 0.9947 - val_loss: 0.1859 - val_accuracy: 0.9730 - val_iou_score: 0.9570
# Epoch 227/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0057 - accuracy: 0.9969 - iou_score: 0.9949 - val_loss: 0.2230 - val_accuracy: 0.9728 - val_iou_score: 0.9565
# Epoch 228/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0057 - accuracy: 0.9967 - iou_score: 0.9946 - val_loss: 0.2491 - val_accuracy: 0.9718 - val_iou_score: 0.9548
# Epoch 229/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0070 - accuracy: 0.9961 - iou_score: 0.9935 - val_loss: 0.2262 - val_accuracy: 0.9713 - val_iou_score: 0.9543
# Epoch 230/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0083 - accuracy: 0.9955 - iou_score: 0.9927 - val_loss: 0.1973 - val_accuracy: 0.9718 - val_iou_score: 0.9553
# Epoch 231/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0135 - accuracy: 0.9936 - iou_score: 0.9893 - val_loss: 0.2251 - val_accuracy: 0.9690 - val_iou_score: 0.9506
# Epoch 232/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0130 - accuracy: 0.9934 - iou_score: 0.9892 - val_loss: 0.1973 - val_accuracy: 0.9684 - val_iou_score: 0.9496
# Epoch 233/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0126 - accuracy: 0.9934 - iou_score: 0.9890 - val_loss: 0.1752 - val_accuracy: 0.9706 - val_iou_score: 0.9530
# Epoch 234/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0082 - accuracy: 0.9958 - iou_score: 0.9931 - val_loss: 0.1845 - val_accuracy: 0.9728 - val_iou_score: 0.9566
# Epoch 235/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0058 - accuracy: 0.9971 - iou_score: 0.9952 - val_loss: 0.2067 - val_accuracy: 0.9715 - val_iou_score: 0.9546
# Epoch 236/1000
# ...
# Epoch 918/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 9.8848e-04 - accuracy: 0.9988 - iou_score: 0.9981 - val_loss: 0.2575 - val_accuracy: 0.9732 - val_iou_score: 0.9574
# Epoch 919/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0030 - accuracy: 0.9981 - iou_score: 0.9968 - val_loss: 0.1921 - val_accuracy: 0.9684 - val_iou_score: 0.9506
# Epoch 920/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0030 - accuracy: 0.9981 - iou_score: 0.9969 - val_loss: 0.1981 - val_accuracy: 0.9737 - val_iou_score: 0.9581
# Epoch 921/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0036 - accuracy: 0.9978 - iou_score: 0.9964 - val_loss: 0.2210 - val_accuracy: 0.9699 - val_iou_score: 0.9521
# Epoch 922/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0018 - accuracy: 0.9986 - iou_score: 0.9977 - val_loss: 0.1847 - val_accuracy: 0.9720 - val_iou_score: 0.9558
# Epoch 923/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0015 - accuracy: 0.9987 - iou_score: 0.9978 - val_loss: 0.1820 - val_accuracy: 0.9740 - val_iou_score: 0.9588
# Epoch 924/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 6.0354e-04 - accuracy: 0.9990 - iou_score: 0.9983 - val_loss: 0.2153 - val_accuracy: 0.9763 - val_iou_score: 0.9622
# Epoch 925/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -5.9216e-04 - accuracy: 0.9995 - iou_score: 0.9991 - val_loss: 0.2168 - val_accuracy: 0.9750 - val_iou_score: 0.9602
# Epoch 926/1000
# 15/15 [==============================] - 2s 141ms/step - loss: -0.0011 - accuracy: 0.9997 - iou_score: 0.9994 - val_loss: 0.2281 - val_accuracy: 0.9748 - val_iou_score: 0.9599
# Epoch 927/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0014 - accuracy: 0.9998 - iou_score: 0.9996 - val_loss: 0.2288 - val_accuracy: 0.9749 - val_iou_score: 0.9602
# Epoch 928/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0014 - accuracy: 0.9997 - iou_score: 0.9995 - val_loss: 0.2396 - val_accuracy: 0.9767 - val_iou_score: 0.9628
# Epoch 929/1000
# 15/15 [==============================] - 2s 141ms/step - loss: -0.0014 - accuracy: 0.9997 - iou_score: 0.9996 - val_loss: 0.2435 - val_accuracy: 0.9748 - val_iou_score: 0.9600
# Epoch 930/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0016 - accuracy: 0.9998 - iou_score: 0.9997 - val_loss: 0.2515 - val_accuracy: 0.9742 - val_iou_score: 0.9592
# Epoch 931/1000
# 15/15 [==============================] - 2s 139ms/step - loss: -0.0017 - accuracy: 0.9998 - iou_score: 0.9997 - val_loss: 0.2528 - val_accuracy: 0.9764 - val_iou_score: 0.9624
# Epoch 932/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0019 - accuracy: 0.9999 - iou_score: 0.9998 - val_loss: 0.2498 - val_accuracy: 0.9750 - val_iou_score: 0.9604
# Epoch 933/1000
# 15/15 [==============================] - 2s 140ms/step - loss: -0.0020 - accuracy: 0.9999 - iou_score: 0.9999 - val_loss: 0.2628 - val_accuracy: 0.9752 - val_iou_score: 0.9605
# Epoch 934/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0021 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9755 - val_iou_score: 0.9611
# Epoch 935/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0021 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 936/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0021 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2693 - val_accuracy: 0.9753 - val_iou_score: 0.9608
# Epoch 937/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9753 - val_iou_score: 0.9608
# Epoch 938/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2737 - val_accuracy: 0.9753 - val_iou_score: 0.9608
# Epoch 939/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 940/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9753 - val_iou_score: 0.9608
# Epoch 941/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 942/1000
# 15/15 [==============================] - 2s 140ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 943/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 944/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2859 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 945/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 946/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 947/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2907 - val_accuracy: 0.9752 - val_iou_score: 0.9607
# Epoch 948/1000
# 15/15 [==============================] - 2s 140ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2921 - val_accuracy: 0.9752 - val_iou_score: 0.9607
# Epoch 949/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2934 - val_accuracy: 0.9753 - val_iou_score: 0.9607
# Epoch 950/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 951/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 952/1000
# 15/15 [==============================] - 2s 140ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 953/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 954/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.2994 - val_accuracy: 0.9751 - val_iou_score: 0.9605
# Epoch 955/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9752 - val_iou_score: 0.9605
# Epoch 956/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3012 - val_accuracy: 0.9751 - val_iou_score: 0.9605
# Epoch 957/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 958/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.9752 - val_iou_score: 0.9606
# Epoch 959/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3040 - val_accuracy: 0.9752 - val_iou_score: 0.9605
# Epoch 960/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3022 - val_accuracy: 0.9752 - val_iou_score: 0.9607
# Epoch 961/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3040 - val_accuracy: 0.9751 - val_iou_score: 0.9605
# Epoch 962/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0022 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3040 - val_accuracy: 0.9752 - val_iou_score: 0.9605
# Epoch 963/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0021 - accuracy: 1.0000 - iou_score: 1.0000 - val_loss: 0.3048 - val_accuracy: 0.9751 - val_iou_score: 0.9605
# Epoch 964/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0020 - accuracy: 0.9999 - iou_score: 0.9999 - val_loss: 0.3046 - val_accuracy: 0.9744 - val_iou_score: 0.9594
# Epoch 965/1000
# 15/15 [==============================] - 2s 134ms/step - loss: -0.0015 - accuracy: 0.9998 - iou_score: 0.9997 - val_loss: 0.3082 - val_accuracy: 0.9753 - val_iou_score: 0.9606
# Epoch 966/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -6.5987e-06 - accuracy: 0.9994 - iou_score: 0.9990 - val_loss: 0.3087 - val_accuracy: 0.9737 - val_iou_score: 0.9580
# Epoch 967/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0028 - accuracy: 0.9985 - iou_score: 0.9974 - val_loss: 0.2262 - val_accuracy: 0.9691 - val_iou_score: 0.9517
# Epoch 968/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0065 - accuracy: 0.9969 - iou_score: 0.9950 - val_loss: 0.2092 - val_accuracy: 0.9716 - val_iou_score: 0.9549
# Epoch 969/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0051 - accuracy: 0.9972 - iou_score: 0.9953 - val_loss: 0.2153 - val_accuracy: 0.9716 - val_iou_score: 0.9545
# Epoch 970/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0026 - accuracy: 0.9983 - iou_score: 0.9973 - val_loss: 0.1648 - val_accuracy: 0.9694 - val_iou_score: 0.9522
# Epoch 971/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0022 - accuracy: 0.9985 - iou_score: 0.9975 - val_loss: 0.1320 - val_accuracy: 0.9765 - val_iou_score: 0.9626
# Epoch 972/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0019 - accuracy: 0.9985 - iou_score: 0.9975 - val_loss: 0.1877 - val_accuracy: 0.9685 - val_iou_score: 0.9504
# Epoch 973/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0034 - accuracy: 0.9982 - iou_score: 0.9971 - val_loss: 0.1625 - val_accuracy: 0.9696 - val_iou_score: 0.9522
# Epoch 974/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0038 - accuracy: 0.9977 - iou_score: 0.9962 - val_loss: 0.1355 - val_accuracy: 0.9767 - val_iou_score: 0.9627
# Epoch 975/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0042 - accuracy: 0.9978 - iou_score: 0.9963 - val_loss: 0.1760 - val_accuracy: 0.9716 - val_iou_score: 0.9546
# Epoch 976/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0122 - accuracy: 0.9957 - iou_score: 0.9929 - val_loss: 0.1963 - val_accuracy: 0.9528 - val_iou_score: 0.9249
# Epoch 977/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0233 - accuracy: 0.9916 - iou_score: 0.9861 - val_loss: 0.1763 - val_accuracy: 0.9664 - val_iou_score: 0.9483
# Epoch 978/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0802 - accuracy: 0.9759 - iou_score: 0.9611 - val_loss: 0.1184 - val_accuracy: 0.9541 - val_iou_score: 0.9278
# Epoch 979/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0862 - accuracy: 0.9725 - iou_score: 0.9560 - val_loss: 0.1418 - val_accuracy: 0.9518 - val_iou_score: 0.9236
# Epoch 980/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0475 - accuracy: 0.9850 - iou_score: 0.9755 - val_loss: 0.1416 - val_accuracy: 0.9644 - val_iou_score: 0.9447
# Epoch 981/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0176 - accuracy: 0.9932 - iou_score: 0.9887 - val_loss: 0.1701 - val_accuracy: 0.9637 - val_iou_score: 0.9430
# Epoch 982/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0126 - accuracy: 0.9946 - iou_score: 0.9910 - val_loss: 0.1407 - val_accuracy: 0.9729 - val_iou_score: 0.9569
# Epoch 983/1000
# 15/15 [==============================] - 2s 137ms/step - loss: 0.0079 - accuracy: 0.9962 - iou_score: 0.9937 - val_loss: 0.1353 - val_accuracy: 0.9751 - val_iou_score: 0.9604
# Epoch 984/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0044 - accuracy: 0.9975 - iou_score: 0.9958 - val_loss: 0.1663 - val_accuracy: 0.9754 - val_iou_score: 0.9607
# Epoch 985/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0023 - accuracy: 0.9984 - iou_score: 0.9973 - val_loss: 0.1836 - val_accuracy: 0.9755 - val_iou_score: 0.9609
# Epoch 986/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0012 - accuracy: 0.9988 - iou_score: 0.9980 - val_loss: 0.2100 - val_accuracy: 0.9756 - val_iou_score: 0.9611
# Epoch 987/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 5.0626e-04 - accuracy: 0.9990 - iou_score: 0.9984 - val_loss: 0.2279 - val_accuracy: 0.9758 - val_iou_score: 0.9613
# Epoch 988/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 2.8652e-04 - accuracy: 0.9991 - iou_score: 0.9985 - val_loss: 0.2341 - val_accuracy: 0.9754 - val_iou_score: 0.9608
# Epoch 989/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 6.2073e-04 - accuracy: 0.9989 - iou_score: 0.9982 - val_loss: 0.2277 - val_accuracy: 0.9753 - val_iou_score: 0.9608
# Epoch 990/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0018 - accuracy: 0.9985 - iou_score: 0.9974 - val_loss: 0.2363 - val_accuracy: 0.9748 - val_iou_score: 0.9599
# Epoch 991/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 0.0063 - accuracy: 0.9971 - iou_score: 0.9951 - val_loss: 0.2333 - val_accuracy: 0.9736 - val_iou_score: 0.9577
# Epoch 992/1000
# 15/15 [==============================] - 2s 140ms/step - loss: 0.0061 - accuracy: 0.9966 - iou_score: 0.9945 - val_loss: 0.1667 - val_accuracy: 0.9746 - val_iou_score: 0.9595
# Epoch 993/1000
# 15/15 [==============================] - 2s 135ms/step - loss: 0.0030 - accuracy: 0.9982 - iou_score: 0.9970 - val_loss: 0.1804 - val_accuracy: 0.9751 - val_iou_score: 0.9603
# Epoch 994/1000
# 15/15 [==============================] - 2s 136ms/step - loss: 0.0015 - accuracy: 0.9988 - iou_score: 0.9980 - val_loss: 0.2262 - val_accuracy: 0.9751 - val_iou_score: 0.9602
# Epoch 995/1000
# 15/15 [==============================] - 2s 134ms/step - loss: 2.6256e-04 - accuracy: 0.9992 - iou_score: 0.9987 - val_loss: 0.2263 - val_accuracy: 0.9756 - val_iou_score: 0.9611
# Epoch 996/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -5.5208e-04 - accuracy: 0.9996 - iou_score: 0.9993 - val_loss: 0.2393 - val_accuracy: 0.9756 - val_iou_score: 0.9611
# Epoch 997/1000
# 15/15 [==============================] - 2s 137ms/step - loss: -9.4950e-04 - accuracy: 0.9997 - iou_score: 0.9994 - val_loss: 0.2640 - val_accuracy: 0.9754 - val_iou_score: 0.9607
# Epoch 998/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0012 - accuracy: 0.9997 - iou_score: 0.9996 - val_loss: 0.2600 - val_accuracy: 0.9756 - val_iou_score: 0.9611
# Epoch 999/1000
# 15/15 [==============================] - 2s 136ms/step - loss: -0.0014 - accuracy: 0.9998 - iou_score: 0.9997 - val_loss: 0.2671 - val_accuracy: 0.9755 - val_iou_score: 0.9609
# Epoch 1000/1000
# 15/15 [==============================] - 2s 135ms/step - loss: -0.0015 - accuracy: 0.9998 - iou_score: 0.9997 - val_loss: 0.2811 - val_accuracy: 0.9754 - val_iou_score: 0.9608

# %%
MODEL_PATH = './models_weight/'
SVAED_MODEL_NAME = MODEL_PATH + 'simple2D_512' + '_' + str(EPOCHS) + '.hdf5'

model.save(SVAED_MODEL_NAME)

# %% [markdown]
# ### visualize the train process

# %%
# visualize

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # predict on test dataset

# %%
# load in the model

MODEL_PATH = './models_weight/'

from keras.models import load_model
my_model = load_model(SVAED_MODEL_NAME, compile=False)
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.

# %% [markdown]
# ### generator for test

# %%
# test generator

batch_size_test = 32

test_img_datagen = imageLoader(test_img_dir, test_img_list,
                               test_msk_dir, test_msk_list, batch_size_test)

# %%
# inspect generator data

img_test, msk_test = test_img_datagen.__next__()

print('image gen:', img_test.shape, img_test.min(), img_test.max())
print('mask gen:', msk_test.shape, msk_test.min(), msk_test.max(), np.unique(msk_test))

n_slice = random.randint(0, img_test.shape[0]-1)
# n_slice = 15
print('slice num:', n_slice)
visusalizeIMG(n_slice, img_test, msk_test)
# Out:
# image gen: (30, 256, 256) 0.0 1.0
# mask gen: (30, 256, 256) 0.0 1.0 [0. 1.]
# slice num: 18

# %% [markdown]
# ### predict

# %%
# prediction

pred_test = model.predict(img_test)
print(pred_test.shape, pred_test.min(), pred_test.max())
# Out:
# (30, 256, 256, 1) 0.0 1.0

# %%
# visualization

n_slice = random.randint(0, pred_test.shape[0]-1)
# n_slice = 15
print('slice num:', n_slice)
visusalizeIMG(n_slice, pred_test.squeeze(), msk_test)
# Out:
# slice num: 2

# %%
# calculate the IOU for one test batch

from tensorflow.keras.metrics import MeanIoU

n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)

# pred_test_argmax = pred_test.squeeze()
IOU_keras.update_state(pred_test.squeeze(), msk_test)
print("pred Mean IoU =", IOU_keras.result().numpy())
# Out:
# pred Mean IoU = 0.6535115

# %% [markdown]
# ### document the test result

# %%
# test one image

i = 9

tIMG = img_test[i,...] # input
tPred = pred_test.squeeze()[i,...] # prediction
tMask = msk_test[i,...] # GT

bar = np.ones((tIMG.shape[0], 15))   # lines
combTemp = np.concatenate((tIMG, bar, tPred, bar, tMask), axis=1) * 255

print(combTemp.max())

plt.imshow(combTemp, cmap='gray')
plt.axis('off')
# Out:
# 255.0
# (-0.5, 797.5, 255.5, -0.5)

# %%
# document in neptune

for i in range(pred_test.shape[0]):
    tIMG = img_test[i,...] # input
    tPred = pred_test.squeeze()[i,...] # prediction
    tMask = msk_test[i,...] # GT
    
    bar = np.ones((tIMG.shape[0], 15))   # lines
    combTemp = np.concatenate((tIMG, bar, tPred, bar, tMask), axis=1) # upload [0, 1]
    
    
    # upload the test images to neptune
    if DOCUMENT:
        # upload the test results into neptune with handle 'description'
        run["test/sample_images"].log(neptune.types.File.as_image(combTemp), name=str(i), description='test images')

# %% [markdown]
# ## stop neptune

# %%
# stop the neptune
if DOCUMENT:
    run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 47 operations to synchronize with Neptune. Do not kill this process.
# All 47 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/leeleeroy/digitalConfocal-zebrafish/e/DIGZ-11

# %% [markdown]
# ## predict a whole stack

# %% [markdown]
# ### load in the image stacks

# %%
# load in

preSegStacks = np.load('/bigdata/casus/MLID/RuiLi/Data/LM/segStacks/segStacks_170411_24.npy')
print(preSegStacks.shape, preSegStacks.min(), preSegStacks.max())
# Out:
# (4, 20, 256, 256) 0 255

# %%
# visualize
import random

n_slice = random.randint(0, preSegStacks.shape[1])
subShow(preSegStacks[0,n_slice,:,:,], preSegStacks[0,n_slice + 1,:,:,])

# %% [markdown]
# ### predict in model

# %%
# predict per stacks

predictStacks = []

for stack in range(preSegStacks.shape[0]):
    stackTemp = preSegStacks[stack,...] / 255 # uint8 -> [0, 1]
    predTemp = model.predict(stackTemp)
    
    predictStacks.append(predTemp.squeeze())
    
predictStacks = np.asarray(predictStacks)
print(predictStacks.shape, predictStacks.min(), predictStacks.max())
# Out:
# (4, 20, 256, 256) 0.0 1.0

# %%
# visualize

n_slice = random.randint(0, predictStacks.shape[1]-1)
print('slice num:', n_slice)
subShow(predictStacks[0,n_slice,:,:,], predictStacks[0,n_slice + 1,:,:,])
# Out:
# slice num: 16

# %% [markdown]
# ### take seg pixels from mask

# %%
# seg one stack images [NUM, W, H]. msk as bool, img as [0, 1]

import numpy as np

def segPixels(mskStack, imgStack):
    
    segStack = []
    for num in range(mskStack.shape[0]):
        
        mskTemp = mskStack[num,...]
        imgTemp = imgStack[num,...]
        
        segTemp = np.zeros(imgTemp.shape)
        # print(mskTemp.shape)
        
        posTemp = np.where(mskTemp)

        for i in range(posTemp[0].shape[0]):
            segTemp[posTemp[0][i],posTemp[1][i]] = imgTemp[posTemp[0][i],posTemp[1][i]]
        
        segStack.append(segTemp)
        
    return np.asarray(segStack)

# %%
# binarize the mask stacks

predictStacks = predictStacks > 0.2

n_slice = random.randint(0, predictStacks.shape[1]-1)
print('slice num:', n_slice)
subShow(predictStacks[0,n_slice,:,:,], predictStacks[0,n_slice + 1,:,:,])
# Out:
# slice num: 10

# %%
# seg all stacks

segStacks = []

for stack in range(predictStacks.shape[0]):
    
    tempMskStack = predictStacks[stack]
    tempImgStack = preSegStacks[stack]
    
    tempSegStack = segPixels(tempMskStack, tempImgStack)
    
    segStacks.append(tempSegStack)

segStacks = np.asarray(segStacks)
print(segStacks.shape)
# Out:
# (4, 20, 256, 256)

# %%
# visualize
import random

n_stack = 0
n_slice = random.randint(0, segStacks.shape[1]-1)

subShow(segStacks[n_stack, n_slice, :, :], preSegStacks[n_stack, n_slice, :, :])

# %% [markdown]
# ### save image for offline visualize

# %%
# save as tif for offline visualize

import numpy as np
from tifffile import imsave

SEG_PATH = './reports/UNet2D_vanilla/'

for stack in range(segStacks.shape[0]):
    
    tempStack = segStacks[stack,...]   
    imsave(SEG_PATH + str(stack) +'_seg_result_deep_512' + '.tif', tempStack)
